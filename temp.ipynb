# %%
import os
files = os.listdir("static/favicon/")
files[0]
  
files = os.listdir("templates/")
files

fol = os.listdir('../webpersona/')
pages = [page for page in fol if not os.path.isdir(page) ]
pages 

ff = os.listdir('templates/')
f = [page for page in ff if  os.path.isdir(page)]
f
b = os.path.isdir('templates/partials/')
b


def listDirectories(path="../webpersona" dirDict={}):
    folders = [fold for fold in os.listdir(path) if os.path.isdir(path+fold)]
    files = [fold for fold in os.listdir(path) if not os.path.isdir(path+fold)]
    dirDict = {}
    print(fol)
# Out:
# {'__name__': 'os',
# ...

# %%
f = open("static/root.css","r")
r = f.readlines()
r[-15:]
# Out:
# ['/* Favorite */\n',
#  ':root {\n',
#  '  --navbar: linear-gradient(135deg, #141e30, #243b55);\n',
#  '  --navbarText: #fdfdfd;\n',
#  '  --brandname: linear-gradient(135deg, #c471f5, #fa71cd);\n',
#  '  --buttons: linear-gradient(135deg, #667eea, #764ba2);\n',
#  '  --button-hover: linear-gradient(135deg, #6a11cb, #2575fc);\n',
#  '  --main-bg: linear-gradient(135deg, #ece9e6, #ffffff);\n',
#  '  --main-heading: linear-gradient(135deg, #3a1c71, #d76d77, #ffaf7b);\n',
#  '  --main-subheading: linear-gradient(135deg, #ffecd2, #fcb69f);\n',
#  '  --main-text: #2c3e50;\n',
#  '  --childDivs-bg: linear-gradient(135deg, #dfe9f3, #ffffff);\n',
#  '  --footer-bg: linear-gradient(135deg, #2c3e50, #4ca1af);\n',
#  '  --highlight: linear-gradient(135deg, #fa709a, #fee140);\n',
#  '}']

# %%
s = "50g0px"
a=0
num = str()
for i,v in enumerate(s):
    if v.isnumeric() == False:
        break
    else:
        num = num+v
num
# Out:
# '50'

# %%
f = 'dfjdsoapj}}sfjmnsf}}sdfakj}}'
f.rfind('}')
# Out:
# 27

# %%
import re
with open('templates/Home.html', "r") as f:
    content = f.readlines()
# content = content.encode().decode('unicode_escape')
# # print(content)
# html = ['', '\t<div class="extraUp"><i class="fas fa-pen-fancy vis" contenteditable="False"></i>fd</div>', '\t<nav>', '\t\t<div class="nav-brand">', '\t\t\t<img src="../../static/logo/logo.png" alt="webpersona" id="Logo" contenteditable="False">', '\t\t\t<h1>WEBPERSOdfNA</h1>', '\t\t</div>', '', '\t\t<button class="hamburger" type="button" contenteditable="False">', '\t\t\t<span></span>', '\t\t\t<span></span>', '\t\t\t<span></span>', '\t\t</button>', '', '\t\t<ul type="none">', '\t\t\t<li>', '\t\t\t\t<details>', '\t\t\t\t\t<summary>About</summary>', '\t\t\t\t\t<div>Write Your Own</div>', '\t\t\t\t</details>', '\t\t\t</li>', '\t\t\t<li>', '\t\t\t\t<details>', '\t\t\t\t\t<summary>Prodvcucts</summary>', '\t\t\t\t\t<div>hiiixcvvz afnd what are doimg bhai mera name to thik thal&nbsp; what are you talking about</div>', '\t\t\t\t</details>', '\t\t\t</li>', '\t\t\t<li>', '\t\t\t\t<details>', '\t\t\t\t\t<summary>New</summary>', '\t\t\t\t\t<div>hiii</div>', '\t\t\t\t</details>', '\t\t\t</li>', '\t\t\t<!--NO--><li contenteditable="false" class="showHome">', '\t\t\t\t<a href="">Home</a>', '\t\t\t</li>', '\t\t\t<button>Login</button>', '\t\t\t<button>Sign Up</button>', '\t\t</ul>', '', '\t\t<div id="buttons">', '\t\t\t<button>Losdcvgin</button>', '\t\t\t<button>Sign Up</button>', '\t\t</div>', '\t</nav>', '\t<div class="extraDown"><i class="fas fa-pen-fancy vis" contenteditable="false"></i>fvdfgv</div>', '']
# if html[0] == '':
#     html.pop(0)
# if html[len(html)-1]=='':
#     html.pop(len(html)-1)
    
# block_id = 'header.html'
# pattern = fr'(<[^>]+id=["\']{block_id}["\'][^>]*>)'
# closing_tag = f'</{block_id.removesuffix(".html")}>'

# # 1. Find start of block
# start_idx = None
# for i, line in enumerate(content):
#     if re.match(pattern, line):
#         start_idx = i
#         break

# if start_idx is None:
#     raise ValueError("Start tag not found")

# # 2. Find end of block
# end_idx = None
# for i in range(start_idx + 1, len(content)):
#     if closing_tag in content[i]:
#         end_idx = i
#         break

# if end_idx is None:
#     raise ValueError("Closing tag not found")

# # 3. Prepare prefix and suffix
# prefix = content[:start_idx + 1]
# suffix = content[end_idx:]

# # 4. Extract block to replace
# oldblock = content[start_idx + 1:end_idx]

# # 5. Replace line-by-line
# new = []
# jinja_pattern = r'{[{%#].*?[}%]}'  # Matches all Jinja tag types

# for a, line in enumerate(oldblock):
#     if a >= len(html):
#         break

#     updated_line = html[a]

#     if "<!--NO-->" in line:
#         new.append(line)  # Preserve line
#     elif re.search(jinja_pattern, line.strip()):
#         jinja_match = re.search(jinja_pattern, line)
#         if jinja_match:
#             preserved = jinja_match.group()
#             # inject Jinja back into updated line
#             rebuilt = ''
#             i = 0
#             once = True
#             for l in updated_line:
#                 if line[i] != '{':
#                     rebuilt +=  l
#                 elif line[i] == '{' and once==True:
#                     rebuilt += line[line.find('{'):line.rfind('}')+1]
#                     g = line.rfind('}')-line.find('{')
#                     # i = i+g
#                     once = False
#                 i=i+1
            
#             half_1 = rebuilt[:rebuilt.rfind('}')+1]
#             half_2 = rebuilt[rebuilt.rfind('}')+1:]
#             print(half_2)
#             for t in half_2:
#                 if t == '"':
#                     break
#                 elif t != '"':
#                     half_2 = half_2.removeprefix(t)
#             print(half_2)

#             rebuilt = half_1+half_2
#             new.append(rebuilt)        
            
#         else:
#             new.append(updated_line)        
#     else:
#         new.append(updated_line)

# new
# Combine new content
# final_content = prefix + new + suffix

# # Optional: write to file
# # with open('templates/partials/header.html', "w", encoding='utf-8') as f:
# #     f.writelines(final_content)

# # Output preview
# for line in final_content:
#     print(line.rstrip())

# '\t<div class="extraUp"><i class="fas fa-pen-fancy id="{{dfnsal}}fg" {{\'vis\' if all[\'body_content_editable\'] else \'non-vis\'}}vis" contenteditable="False"></i>fd</d'

# %%
print(content)
for i in range(len(content)-1,1,-1):
    if '<!--Close-->' in content[i]:
        print(i)
        break
# Out:
# ['<style>\n', '\t@keyframes float {\n', '\t\t0% {\n', '\t\t\ttransform: translateY(0px);\n', '\t\t}\n', '\t\t50% {\n', '\t\t\ttransform: translateY(-20px);\n', '\t\t}\n', '\t\t100% {\n', '\t\t\ttransform: translateY(0px);\n', '\t\t}\n', '\t}\n', '\n', '\t@keyframes pulse {\n', '\t\t0% {\n', '\t\t\ttransform: scale(1);\n', '\t\t}\n', '\t\t50% {\n', '\t\t\ttransform: scale(1.05);\n', '\t\t}\n', '\t\t100% {\n', '\t\t\ttransform: scale(1);\n', '\t\t}\n', '\t}\n', '\n', '\t@keyframes gradientBG {\n', '\t\t0% {\n', '\t\t\tbackground-position: 0% 50%;\n', '\t\t}\n', '\t\t50% {\n', '\t\t\tbackground-position: 100% 50%;\n', '\t\t}\n', '\t\t100% {\n', '\t\t\tbackground-position: 0% 50%;\n', '\t\t}\n', '\t}\n', '\n', '\t@keyframes slideIn {\n', '\t\t0% {\n', '\t\t\ttransform: translateX(-100px);\n', '\t\t\topacity: 0;\n', '\t\t}\n', '\t\t100% {\n', '\t\t\ttransform: translateX(0);\n', '\t\t\topacity: 1;\n', '\t\t}\n', '\t}\n', '\n', '\t@keyframes fadeUp {\n', '\t\t0% {\n', '\t\t\ttransform: tra
# ...

# %%
bodyF = ['eiur','eri','er']
baseF = ['fdmmor','ersdpkfi','dfer']
baseF+bodyF
# Out:
# ['fdmmor', 'ersdpkfi', 'dfer', 'eiur', 'eri', 'er']

# %%
import os
# Out:
# ['#New Logic\n', "@app.route('/<name>')\n", 'def render_page(name):\n', '    if name not in ["Home.html", "adminPanel.html"]:\n', '        w.currentPage = name\n', '        try:\n', '            return render_template(f"partials/{name}", all=w.__dict__)\n', '        except:\n', '            return render_template(f"{name}", all=w.__dict__)\n', '    else:\n', '        print("dynamic-n")\n', '        if name == "Home.html":\n', "            return redirect(url_for('Home'))\n", '        else:\n', "            return redirect(url_for('admin'))\n", '            \n', 'if __name__ == "__main__":\n', '    app.run(debug=True)']
